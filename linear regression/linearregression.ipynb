# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

dataset=pd.read_csv(r"C:\Users\USER\Downloads\archive (2)\boston.csv")
dataset
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO       B  LSTAT  Price
# ...

# %%
model=linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x=dataset[['CRIM','ZN','AGE']]
y=dataset['Price']
x,y
# Out:
# (        CRIM    ZN   AGE
#  0    0.00632  18.0  65.2
#  1    0.02731   0.0  78.9
#  2    0.02729   0.0  61.1
#  3    0.03237   0.0  45.8
#  4    0.06905   0.0  54.2
#  ..       ...   ...   ...
#  501  0.06263   0.0  69.1
#  502  0.04527   0.0  76.7
#  503  0.06076   0.0  91.0
#  504  0.10959   0.0  89.3
#  505  0.04741   0.0  80.8
#
#  [506 rows x 3 columns],
#  0      24.0
#  1      21.6
#  2      34.7
#  3      33.4
#  4      36.2
#         ...
#  501    22.4
#  502    20.6
#  503    23.9
#  504    22.0
#  505    11.9
#  Name: Price, Length: 506, dtype: float64)

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[0.05,0.0,30]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24.5809331])

# %%
model.fit(dataset[['CRIM','ZN','AGE']],dataset['Price'])
# Out:
# LinearRegression()

# %%
model.predict([[0.05,0.0,25]])
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24.82774309])

# %%
from sklearn.metrics import mean_squared_error
model.coef_
# Out:
# array([-0.31192812,  0.08514621, -0.049362  ])

# %%
model.intercept_
# Out:
# 26.0773894408328

# %%
import seaborn as sns

sns.scatterplot(x)
# Out:
# <Axes: >

# %%
y=(0.05*-0.3119)+(0.0*0.085)+(25*-0.049)+26.077
y
# Out:
# 24.836405000000003
